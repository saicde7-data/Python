# %% [markdown]
# #### Declaring variable (Numerical) and assigning a value

# %%
x = 23
x
# Out:
# 23

# %% [markdown]
# #### Finding the type of the Variable declared above

# %%
type(x)
# Out:
# int

# %% [markdown]
# #### Declaring variable (String) and assigning a value

# %%
x = 'Python'
x
# Out:
# 'Python'

# %% [markdown]
# #### Finding the type of the Variable declared above

# %%
type(x)
# Out:
# str
