# %% [markdown]
# #### Adding two lists

# %%
l
l + ml
# Out:
# ['chris gayle', 'sachin tendulkar', 'ross taylor', True, 5.5, 'xyz', 'abc', 0]

# %% [markdown]
# #### We have to assign to a variable when we concatenate two lists

# %%
l, ml
# Out:
# (['chris gayle', 'sachin tendulkar', 'ross taylor'],
#  [True, 5.5, 'xyz', 'abc', 0])

# %% [markdown]
# #### Assigned to a list by concatenating two lists

# %%
l= l + ml
l
# Out:
# ['chris gayle', 'sachin tendulkar', 'ross taylor', 0, 'abc', 'xyz', 5.5, True]
