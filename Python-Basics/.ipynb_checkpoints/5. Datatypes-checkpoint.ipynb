# %% [markdown]
# ## Data types
#     bool
#     int
#     float
#     complex
#     string
#     List
#     Dictionary
#     Tuple
#     Set

# %% [markdown]
# #### bool

# %%
type(True)
# Out:
# bool

# %% [markdown]
# #### int

# %%
type(23)
# Out:
# int

# %% [markdown]
# #### float

# %%
type(2.56)
# Out:
# float

# %% [markdown]
# #### complex

# %%
type(2+3j)
# Out:
# complex

# %% [markdown]
# #### string

# %%
type("David")
# Out:
# str

# %% [markdown]
# #### List

# %%
z = [1, 2, 3, 4, 5]
z
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# #### Dictionary

# %%
x = {0:'Zero', 1:'One', 2:'Two'}
x
# Out:
# {0: 'Zero', 1: 'One', 2: 'Two'}

# %% [markdown]
# #### Tuple

# %%
x = (1, 1, 2, 3, 4)
x
# Out:
# (1, 1, 2, 3, 4)

# %% [markdown]
# ### Set

# %%
y = {1, 1, 2, 3, 4}

# %%
y
# Out:
# {1, 2, 3, 4}

# %%
x
# Out:
# (1, 1, 2, 3, 4, 4)

# %%
x = (1, 1, 2, 3, 4, 4)
