# %% [markdown]
# ## Comments

# %%
2 + 3 # This is a comment # Esc + M; Esc + Y

# %% [markdown]
# # OPERATORS
#     ARITHMETIC OPERATORS
#     COMPARISION (RELATIONAL) OPERATORS
#     LOGICAL (BOOLEAN) OPERATORS
#     BITWISE OPERATORS
#     ASSIGNMENT OPERATORS
#     SPECIAL OPERATORS
#         IDENTITY OPERATOR - IS ; IS NOT
#         MEMBERSHIP OPERATOR - IN; NOT IN

# %% [markdown]
# ## Arithmetic Operators
#     Addition; Subtraction; Division; Floor Divison; Modulo; Multiplication; PowerOf

# %%
x = 5

# %%
y = 2

# %%
x + y
# Out:
# 7

# %%
x - y
# Out:
# 3

# %%
x * y
# Out:
# 10

# %%
x / y
# Out:
# 2.5

# %%
2)5(2 --> Quotient (/)
  4
----
1 -->  Reminder (%)

# %%
x % y
# Out:
# 1

# %%
x ** 2
# Out:
# 25

# %%
x // y
# Out:
# 2

# %%
ceil --> 6 (5.7 --> 5 + 1 = 6)
5.2
floor --> 5 (5.7 --> 5)

# %% [markdown]
# ## Comparision Operatos
#     > ; >= ; < ; <= ; == ; !=

# %%
True or False

# %%
x
# Out:
# 5

# %%
x = 10

# %%
x
# Out:
# 10

# %%
y
# Out:
# 2

# %%
(x >= 2) and (y <= 8) # 5 <=2 ==> 5 > 2 or 5 == 2 ==> False or False ==> False or (True) ==> 2 < 8 or 2 ==8 ==> True
# Out:
# True

# %%
x >= 2 # 5 > 2 or 5 == 2 ==> True or False ==> True
# Out:
# True

# %%
x <= 10 # 5 < 10 or 5 == 10 ==> True or False = True
# Out:
# True

# %%
x != 5 # 10 != 5 ==> True
# Out:
# True

# %%
x
# Out:
# 15

# %%
x == 15 # 15 == 15 ==> True
# Out:
# True

# %%
x != 2 # x not equal to 2 ==> 15 is not equal to 2 ==> True
# Out:
# True

# %% [markdown]
# ## Logical Operators
#     and; or ; not

# %%
True and True and True and False = False

# %%
False or False or False or True = True

# %%
(5 > 2) or (3 > 4) # True or False ==> True
# Out:
# True

# %%
not(False) # not(True) ==> False
# Out:
# True

# %% [markdown]
# ## Bitwise Operators
#     &; |; ~; ^; >> ; <<

# %%
x = 3

# %%
y = 5

# %%
x ^ y
# Out:
# 6

# %%
bin(x) # 0010
# Out:
# '0b11'

# %%
bin(y) # 0101
# Out:
# '0b101'

# %%
x
# Out:
# 3

# %%
y << 2
# Out:
# 20

# %% [markdown]
# ## Assignment operators
#     =; +=; -=; *=; /=; %=; &=; **=; >>=; <<=

# %%
x = 2

# %%
x
# Out:
# 2

# %%
x += 2 # x = x + 2 = 2 + 2 = 4

# %%
x
# Out:
# 4

# %%
x -= 2 # x  = x - 2 = 4 - 2 = 2

# %%
x
# Out:
# 2

# %%
x *= 2 # x = x * 2 = 2 * 2 = 4

# %%
x
# Out:
# 4

# %%
x /= 2 # x = x / 2 = 4 / 2 = 2.0

# %%
x
# Out:
# 2.0

# %%
x = 2

# %%
x &= 2 # x = x & 2 = 2 & 2 # 0010 & 0010 = 0010

# %%
x
# Out:
# 2

# %%
x = 5

# %%
x %= 2 # x = x % 2 = 2.0 % 2 = 0

# %%
x
# Out:
# 1

# %%
x = 2

# %%
x **= 2 # x = x ** 2 = 2 ** 2 = 4

# %%
x
# Out:
# 4

# %%
bin(x)
# Out:
# '0b100'

# %%
x >>= 2 # x = x >> 2 = 0100 >> 2 = 0001 = 1

# %%
x
# Out:
# 1

# %%
x <<= 2 # x = x << 2 = 1 << 2 = 0001 << 2 = 0100 = 4

# %%
x
# Out:
# 4

# %% [markdown]
# ## Special Operators
#     is; is not; in; not IN

# %%
x
# Out:
# [1, 2, 3, 4, 5]

# %%
3 not in xb
# Out:
# False

# %%
z = x

# %%
x = [1, 2, 1.0, "Hello"]

# %%
y = [1, 2, 1.0, "Hello"]

# %% [markdown]
# ## MATH LIBRARY
# - Import Math Library
# - Exponent
# - Logarithm
# - PowerOf
# - Square Root
# - Ceiling Value
# - Pi

# %%
import math

# %%
math.exp(1) # e ** 2
# Out:
# 2.718281828459045

# %%
math.log(25, 2.718281828459045)
# Out:
# 2.0

# %%
5 ** 2.0 = 25

# %%
2 ** 3
# Out:
# 8

# %%
math.pow(4, 2)
# Out:
# 16.0

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
math.floor(5.2)
# Out:
# 5

# %%
math.ceil(5.2)
# Out:
# 6

# %%
math.pi
# Out:
# 3.141592653589793

# %% [markdown]
# ## VARIABLES
# - Numerical Variable and it's type
# - String Variable and it's type

# %%
z = "This is a Machine Learning course."

# %%
z
# Out:
# 'This is a Machine Learning course.'

# %%
type(z)
# Out:
# str

# %%
z = 5.8

# %%
type(z)
# Out:
# float

# %% [markdown]
# ## Dynamically Typed

# %% [markdown]
# ## Data types
#     bool
#     int
#     float
#     complex
#     string
#     List
#     Dictionary
#     Tuple (Immutable)
#     Set

# %%
x = 2 + 3j

# %%
y = 3 + 4j

# %%
x + y
# Out:
# (5+7j)

# %%
my_list = [1, 2, 3, 4, 5]

# %%
type(my_list)
# Out:
# list

# %%
my_dict = {0:'zero', 1:'one', 2:'two', 3:'three', 4:'four', 5:'five'}

# %%
type(my_dict) # Dictionary
# Out:
# dict

# %%
my_tuple = (1, 2, 3, 4, 5)

# %%
type(my_tuple)
# Out:
# tuple

# %%
my_set = {1, 1, 2, 3, 4, 3, 4, 4, 5, 6, 8, 9}

# %%
my_set # sets are not going to entertain duplicates
# Out:
# {1, 2, 3, 4, 5, 6, 8, 9}

# %%
type(my_set)
# Out:
# set

# %% [markdown]
# ## TYPECASTING
# - Int to Float
# - Float to Int

# %%
x = 5

# %%
type(x)
# Out:
# int

# %%
x
# Out:
# 5

# %%
x = str(x)

# %%
x
# Out:
# '5'

# %%
type(x)
# Out:
# str

# %%
x = float(x)

# %%
x
# Out:
# 5.0

# %%
x = str(x)

# %%
x
# Out:
# '5.0'

# %%
type(x)
# Out:
# str

# %%
y = "5.2"

# %%
float(y)
# Out:
# 5.2

# %% [markdown]
# #### Complex Numbers

# %%
x = x + yj
# Out:
# complex

# %% [markdown]
# ## STRINGS
# - Single Quotes Vs. Double Quotes
# - Length of a String
# - Number wrapped in Quotes
# - Indices (0 to n-1)
# - Reverse Order (Negative Indexing - -1 to -n)
# - Slicing - Doesn't Include Upper Bound & Includes Lower Bound

# %%
x = 'machine learning course hasn\"t start\'ed yet.'

# %%
type(x)
# Out:
# str

# %%
x
# Out:
# 'machine learning course hasn"t start\'ed yet.'

# %%
print(x)
# Out:
# machine learning course hasn"t start'ed yet.

# %%
x  = "One Step"

# %%
len(x)
# Out:
# 11

# %%
x = "Machine Learning"

# %%
Machine Le a   r   n  i  n  g
0123456789 10  11  12 13 14 15
# Out:
#   Cell In[156], line 2
#     012
#     ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
x[::2]
# Out:
# 'McieLann'

# %% [markdown]
# ## BOOLEANS
# - Truth Value Testing
# - Object is True unless it is False explictly

# %% [markdown]
# All values are considered "truthy" except for the following, which are "falsy":
#
# None
#
# False
#
# Zeros, including:
#
# 0
#
# 0.0
#
# 0j
#
# decimal.Decimal(0)
#
# fraction.Fraction(0, 1)
#
# Empty sequences and collections, including:
#
# [] - an empty list
#
# {} - an empty dict
#
# () - an empty tuple
#
# '' - an empty str
#
# b'' - an empty bytes
#
# set() - an empty set
#
# an empty range, like range(0)
#
# objects for which
#
# obj.__bool__() returns False
#
# obj.__len__() returns 0
#
#
# A "truthy" value will satisfy the check performed by if or while statements. We use "truthy" and "falsy" to differentiate from the bool values True and False.

# %%
' ' and ''

# %%
if(-55) {
    statmeent1
    sttaement2
    statement3
}

statement4

# %%
if(condition): # True --> Block will get executed; Or False --> Else --> Skip the block
    statmeent1
    sttaement2
    statement3
    statement4

statement5

# %%
x = 2

# %%
if(x + 2 - 8 + 4): # condition > 0 ==> True; or else False; It is not even Condition
    print("junk")
    print("something else")
    print("somethign other than that")
    
print("outside of it")
# Out:
# outside of it

# %% [markdown]
# ## Special characters in string
# - Print Apostrophe
# - Print Apostrophe using \
# - Print BackSlash
# - split method
# - strip method
# - string concatenation
# - Strings are Immutable

# %%
x = "one,two,three,four,five"

# %%
x.split(sep=",")
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
y = "    Machine Learning   "

# %%
y.strip()
# Out:
# 'Machine Learning'

# %%
y
# Out:
# '    Machine Learning   '

# %%
y.strip()
# Out:
# 'Machine Learning'

# %%
x = "Machine"

# %%
y = "Learning"

# %%
type(x), type(y)
# Out:
# (str, str)

# %%
x +' ' +y + str(2)
# Out:
# 'Machine Learning2'

# %%
x = "Machine"

# %%
x[3:5] = "HI!!!"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 x[3:5] = "HI!!!"
#
# TypeError: 'str' object does not support item assignment

# %%
x = "Learning"

# %%
x
# Out:
# 'Learning'
