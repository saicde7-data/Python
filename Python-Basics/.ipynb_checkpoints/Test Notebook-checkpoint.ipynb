# %%
Shift + Enter
Ctrl + Enter
Esc + A ==> Creates the Cell Block above to the existing one
Esc + B ==> Creates the cell block below to the existing one
Esc + DD --> Delete the cell block
Esc + Z --> Undo
Esc + M --> Convert Code block to Markdown Block
Esc + Y --> Convert Markdown block to Code Block

# %%
2 + 5
# Out:
# 7

# %%
2 + 11
# Out:
# 13

# %%
2 +8
# Out:
# 10

# %% [markdown]
# # Heading 1

# %% [markdown]
# ## Heading 2

# %% [markdown]
# ### Heading 3

# %% [markdown]
# #### Heading 4

# %% [markdown]
# ##### Heading 5

# %% [markdown]
# ###### Heading 6
