# %% [markdown]
# #### Typecasting from int to float

# %%
x = float(23)
type(x), x
# Out:
# (float, 23.0)

# %% [markdown]
# #### Typecasting from float to int

# %%
x = int(10.6)
x
# Out:
# 10

# %% [markdown]
# #### Complex Numbers

# %%
complex(2,3)
# Out:
# (2+3j)
