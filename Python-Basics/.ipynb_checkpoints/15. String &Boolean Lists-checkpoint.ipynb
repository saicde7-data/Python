# %% [markdown]
# #### String List

# %%
sl = ['Hello', 'and','World', 'join', 'like', 'this']
type(sl)
# Out:
# list

# %% [markdown]
# #### Boolean List

# %%
bl = [True, False, False]
bl
# Out:
# [True, False, False]

# %% [markdown]
# #### Mixed Lists

# %%
mixed = ['Hello', 1, 2.5, [1, 2, 3]]
mixed
# Out:
# ['Hello', 1, 2.5, [1, 2, 3]]
