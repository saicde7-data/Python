# %%
# Shift + Enter
# Ctrl + Enter
# Esc + A --> Create a Code block on top of the existing code block
# Esc + DD --> Delete the Block
# Esc + B --> Create a Code block below to the existing code block
# Esc + M --> Converts Code block to Markdown
# Esc + Y --> Converts Markdown to Code Block

# %%
4 + 9
# Out:
# 13

# %%
# This is machine learning
2 + 4
# Out:
# 6

# %%
2 + 8
# Out:
# 10

# %% [markdown]
# # Heading 1

# %% [markdown]
# ## Heading 2

# %% [markdown]
# ### Heading 3

# %% [markdown]
# #### Heading 4

# %% [markdown]
# ##### Heading 5

# %% [markdown]
# ###### Heading 6

# %% [markdown]
# This is machine learning
#
# 1. This is line1
# 2. This is line2
# 3. This is line3

# %%
- This is line1
- This is line2
