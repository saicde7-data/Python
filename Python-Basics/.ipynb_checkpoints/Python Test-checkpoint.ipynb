# %%
2 + 6
# Out:
# 8

# %% [markdown]
# Shift + Enter
# Ctrl + Enter
# Esc + A --> will create a code block on top of the existing one
# Esc + B --> Will create a code block below to the existing one
# Esc + dd --> to delete a block
# Esc + M --> To convert Code block to Markdown Block
# Esc + Y --> To convert Markdown to Code Block

# %% [markdown]
# # Heading 1

# %%
# Addition
2 + 3
# Out:
# 5

# %%
2 + 3
# Out:
# 5
