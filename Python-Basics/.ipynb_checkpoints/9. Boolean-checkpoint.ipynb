# %%
x = 23
x > 100
# Out:
# False

# %%
y = 23
x == y
# Out:
# True

# %%
4 < 23
# Out:
# True

# %%
'abc' == 'abc'
'Abc' == 'abc'
# Out:
# False

# %% [markdown]
# #### Truth Value Testing:

# %%
print(False == 0)
print(True == 0)
print(True == 1)
print(False == False)
# Out:
# True
# False
# True
# True

# %% [markdown]
# #### Object is true by default unless it is false explictly

# %%
x = -23
y = 0
z = True
w = None

if x: print('x is true')

if y: print('y is true')
    
if z: print('z is true')
    
if w: print('w is true')
# Out:
# x is true
# z is true
