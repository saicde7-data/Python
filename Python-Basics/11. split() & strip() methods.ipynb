# %% [markdown]
# ### Splitting a string   -   Using "split()"

# %%
s = "David Beckham"
s1 = s.split() #separator
s1
# Out:
# ['David', 'Beckham']

# %%
s2 = 'one, two, three, four, five'
s2 = s2.split(', ')
s2
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
ranstring = 'abc^sdfkl^asdf92^234'
ranstring1 = new.split('^')
ranstring1
# Out:
# ['abc', 'sdfkl', 'asdf92', '234']

# %%
ranstring = 'abc^sdfkl^asdf92^234'
new.split('^')[1]
# Out:
# 'sdfkl'

# %%
'one two three four five'.split(' ', 3)
# Out:
# ['one', 'two', 'three', 'four five']

# %% [markdown]
# #### Stripping blank space at the start and end of a string

# %%
' David Beckham '.strip()
# Out:
# 'David Beckham'

# %% [markdown]
# #### String concatenation

# %%
s1 = 'David'
s2 = 'Beckham'
s1 + s2
# Out:
# 'DavidBeckham'

# %% [markdown]
# ##### Add space between words in a String

# %%
s1 + ' ' + s2
# Out:
# 'David Beckham'

# %% [markdown]
# #### Strings are not mutable

# %%
s
# Out:
# 'David Beckham'

# %%
s[0]
# Out:
# 'D'

# %%
s[0] = 'Z'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-359-af1f7896462d> in <module>
# ----> 1 s[0] = 'Z'
#
# TypeError: 'str' object does not support item assignment
